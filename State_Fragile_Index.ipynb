# %% [markdown]
# # Fragile State Analysis

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import plotly.offline as pyo
import plotly.graph_objs as go
import plotly.figure_factory as ff
import plotly.express as px
from plotly.subplots import make_subplots

import dash
import dash_core_components as dcc
import dash_html_components as html

pd.set_option('float_format', '{:,.2f}'.format)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
import statsmodels.api as sm

from sklearn.cluster import KMeans 
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Section I: FSI

# %% [markdown]
# ## Part 1: Preprocessing

# %%
df_2019 = pd.read_excel('FSI_DATA/fsi-2019.xlsx')
df_2018 = pd.read_excel('FSI_DATA/fsi-2018.xlsx')
df_2017 = pd.read_excel('FSI_DATA/fsi-2017.xlsx')
df_2016 = pd.read_excel('FSI_DATA/fsi-2016.xlsx')
df_2015 = pd.read_excel('FSI_DATA/fsi-2015.xlsx')
df_2014 = pd.read_excel('FSI_DATA/fsi-2014.xlsx')
df_2013 = pd.read_excel('FSI_DATA/fsi-2013.xlsx')
df_2012 = pd.read_excel('FSI_DATA/fsi-2012.xlsx')
df_2011 = pd.read_excel('FSI_DATA/fsi-2011.xlsx')
df_2010 = pd.read_excel('FSI_DATA/fsi-2010.xlsx')
df_2009 = pd.read_excel('FSI_DATA/fsi-2009.xlsx')
df_2008 = pd.read_excel('FSI_DATA/fsi-2008.xlsx')
df_2007 = pd.read_excel('FSI_DATA/fsi-2007.xlsx')
df_2006 = pd.read_excel('FSI_DATA/fsi-2006.xlsx')

# %%
frames = [df_2006, df_2007, df_2008, df_2009, df_2010, df_2011, df_2012, df_2013,
          df_2014, df_2015, df_2016, df_2017, df_2018, df_2019]

df = pd.concat(frames, sort=False)

df['Year'] = df['Year'].dt.to_period('Y')

# %% [markdown]
# ## Part 2: Country Analysis

# %% [markdown]
# ### Part 2.1: Functions

# %%
def f_country_dashboard(country, final_year, initial_year):
    dff = df[df['Country']==country]
    dff = dff.drop(['Country', 'Rank', 'Change from Previous Year', 'Total'], axis=1)
    dff = dff.set_index('Year')
    dff = dff.loc[(dff.index >=initial_year) & (dff.index <= final_year)]
    dff = dff.T
    dff['VAR'] = ((dff[final_year] - dff[initial_year])/dff[initial_year])*100
    dff = dff.sort_values(by='VAR', ascending=False)
    
        
    return dff

# %%
def f_country_graph(country):

    country_selected = country

    df_trace1 = f_country_dashboard(country_selected, final_year, initial_year).T

    df_trace1 = df_trace1.drop(['VAR'])
    df_trace1.reset_index(level=0, inplace=True)
    df_trace1['Year'] = pd.to_datetime(df_trace1['Year'], format='%Y')

    x = df_trace1['Year']
    y1= df_trace1.iloc[:, 1]
    y2= df_trace1.iloc[:, 2]
    y3= df_trace1.iloc[:, 3]
    y4= df_trace1.iloc[:, 4]
    y5= df_trace1.iloc[:, 5]


    trace1 = go.Scatter(x=x,
                        y=y1,
                      mode='lines',
                      name=df_trace1.columns.values[1])

    trace2 = go.Scatter(x=x,
                        y=y2,
                      mode='lines',
                      name=df_trace1.columns.values[2])

    trace3 = go.Scatter(x=x,
                        y=y3,
                      mode='lines',
                      name=df_trace1.columns.values[3])

    trace4 = go.Scatter(x=x,
                        y=y4,
                      mode='lines',
                      name=df_trace1.columns.values[4])

    trace5 = go.Scatter(x=x,
                        y=y5,
                      mode='lines',
                      name=df_trace1.columns.values[5])

    data = [trace1, trace2, trace3, trace4, trace5]

    layout = go.Layout(title='Country: {}'.format(country))

    fig = go.Figure(data=data, layout=layout)
    pyo.plot(fig)

# %% [markdown]
# ### Part 2.2: Analysis

# %%
country = 'Venezuela'
final_year = '2019'
initial_year = '2006'

# %%
f_country_dashboard(country, final_year, initial_year)
# Out:
# Year                              2006  2007  2008  2009  2010  2011  2012  \
# E1: Economy                       4.00  4.00  4.60  5.30  5.80  6.10  5.90
# P1: State Legitimacy              7.50  7.50  7.10  7.20  7.20  7.50  7.90
# C2: Factionalized Elites          7.30  7.50  7.50  7.70  7.50  7.30  7.30
# P2: Public Services               7.00  6.30  6.30  5.90  6.10  5.80  6.30
# S2: Refugees and IDPs             4.80  5.20  5.00  5.00  5.10  4.80  4.50
# P3: Human Rights                  7.80  7.90  7.40  7.30  7.20  7.40  7.70
# C3: Group Grievance               6.80  6.80  6.80  7.00  6.80  7.00  6.70
# C1: Security Apparatus            7.50  6.90  6.60  6.90  6.70  7.00  6.70
# X1: External Intervention         6.00  5.70  5.20  5.50  5.70  5.50  5.20
# E3: Human Flight and Brain Drain  7.00  6.90  6.90  6.90  6.70  6.40  6.10
# E2: Economic Inequality           8.00  8.20  8.00  8.00  7.60  7.30  7.20
# S1: Demographic Pressures         7.50  6.90  6.50  6.80  6.30  6.00  5.70
#
# Year                              2013  2014  2015  2016  2017  2018  2019  \
# E1: Economy                       5.40  5.50  6.50  7.00  7.30  8.30  8.60
# P1: State Legitimacy              7.60  7.70  8.60  8.70  8.50  9.00  9.30
# C2: Factionalized Elites          7.30  7.70  8.10  8.20  8.20  8.53  8.80
# P2: Public Services               6.50  7.50  7.20  7.20  7.70  7.80  8.30
# S2: Refugees and IDPs             4.80  5.10  4.80  4.80  4.60  5.10  5.60
# P3: Human Rights                  7.70  7.80  8.30  8.60  8.90  9.00  9.00
# C3: Group Grievance               6.40  6.80  7.30  7.40  7.20  7.30  7.60
# C1: Security Apparatus            6.50  6.20  6.50  6.80  7.30  7.38  7.40
# X1: External Intervention         4.90  4.60  4.30  5.60  5.40  5.50  5.50
# E3: Human Flight and Brain Drain  5.80  5.50  5.20  5.20  5.50  6.00  6.10
# E2: Economic Inequality           6.90  6.90  6.70  6.90  6.70  6.60  6.90
# S1: Demographic Pressures         5.40  5.40  5.10  5.20  5.60  5.70  6.20
#
# Year                                VAR
# E1: Economy                      115.00
# P1: State Legitimacy              24.00
# C2: Factionalized Elites          20.55
# P2: Public Services               18.57
# S2: Refugees and IDPs             16.67
# P3: Human Rights                  15.38
# C3: Group Grievance               11.76
# C1: Security Apparatus            -1.33
# X1: External Intervention         -8.33
# E3: Human Flight and Brain Drain -12.86
# E2: Economic Inequality          -13.75
# S1: Demographic Pressures        -17.33

# %%
f_country_graph(country)

# %% [markdown]
# ## Part 3: General Analysis

# %%
# Define the year for the analysis:

year = '2019'

# %% [markdown]
# ### Part 3.1: Preprocessing

# %%
# Clean the Data
dff_year = df[df['Year']==year]
dff_year = dff_year.drop(['Year', 'Rank', 'Change from Previous Year'], axis=1)
dff_year = dff_year.set_index('Country')

# Normalize the Data
X = dff_year.values[:,1:]
X = np.nan_to_num(X)
Clus_dataSet = StandardScaler().fit_transform(X)

# %% [markdown]
# ### Part 3.2: Clustering

# %%
clusterNum = 5
k_means = KMeans(init = "k-means++", n_clusters = clusterNum, n_init = 12)
k_means.fit(X)
labels = k_means.labels_

# %%
dff_year["Clus_km"] = labels

# %%
def f_cluster_resumen(cluster):
    
    dff_year_group = dff_year[dff_year['Clus_km']==cluster] 
    dff_year_group = dff_year_group.groupby('Clus_km').mean()
    
    return dff_year_group.mean()

# %%
clusters = [0,1,2,3,4]

dff_desc_cluster_data = []

for cluster in clusters:
    x = f_cluster_resumen(cluster)
    
    dff_desc_cluster_data.append(x)

pd.DataFrame(dff_desc_cluster_data)
# Out:
#    Total  C1: Security Apparatus  C2: Factionalized Elites  \
# 0  72.82                    6.26                      7.87
# 1  24.24                    2.06                      2.29
# 2  97.22                    8.13                      8.85
# 3  46.59                    3.76                      4.92
# 4  74.84                    5.84                      6.40
#
#    C3: Group Grievance  E1: Economy  E2: Economic Inequality  \
# 0                 7.22         5.29                     5.48
# 1                 3.16         2.57                     1.90
# 2                 8.06         7.56                     7.68
# 3                 4.74         4.18                     3.78
# 4                 4.78         6.90                     7.02
#
#    E3: Human Flight and Brain Drain  P1: State Legitimacy  \
# 0                              5.60                  7.40
# 1                              2.25                  1.19
# 2                              7.18                  8.62
# 3                              4.13                  4.17
# 4                              7.32                  5.64
#
#    P2: Public Services  P3: Human Rights  S1: Demographic Pressures  \
# 0                 4.68              7.02                       5.13
# 1                 1.27              1.57                       1.90
# 2                 8.54              8.13                       8.36
# 3                 2.79              3.65                       3.22
# 4                 6.96              5.39                       7.26
#
#    S2: Refugees and IDPs  X1: External Intervention
# 0                   5.23                       5.63
# 1                   2.67                       1.41
# 2                   8.11                       8.00
# 3                   2.95                       4.29
# 4                   4.61                       6.71

# %% [markdown]
# ### Part 3.3: Functions

# %%
def f_scatter_variables(V1, V2):    
    
    dff_year_g = dff_year
    dff_year_g.reset_index(inplace=True)

    fig = px.scatter(dff_year_g, x=V1, y=V2,
                     color='Clus_km', hover_name='Country')

  
    fig.update_layout(title=go.layout.Title(text='FSI'), showlegend=False)

    pyo.plot(fig)

# %% [markdown]
# ### Part 3.4: Analysis

# %%
# List of variables:

dff_year.columns
# Out:
# Index(['Total', 'C1: Security Apparatus', 'C2: Factionalized Elites',
#        'C3: Group Grievance', 'E1: Economy', 'E2: Economic Inequality',
#        'E3: Human Flight and Brain Drain', 'P1: State Legitimacy',
#        'P2: Public Services', 'P3: Human Rights', 'S1: Demographic Pressures',
#        'S2: Refugees and IDPs', 'X1: External Intervention', 'Clus_km'],
#       dtype='object')

# %%
f_scatter_variables('E1: Economy', 'Total')

# %%
f_scatter_variables('S2: Refugees and IDPs', 'Total')

# %% [markdown]
# ### 3.5: Analysis Country selected versus Cluster

# %%
country = 'Venezuela'

cluster_select = dff_year[dff_year['Country']==country]
cluster_select = cluster_select['Clus_km'].values
print('Country Cluster: {} {}.'.format(country, cluster_select))
# Out:
# Country Cluster: Venezuela [2].

# %%
def f_country_compare__(country, cluster):
    # This function help to identify how good/bad is the country select with respect is cluster peers
    
    # Clean cluster data
    dff_cluster = dff_year[dff_year['Clus_km']==cluster]
    dff_cluster = dff_cluster.drop(['Clus_km'], axis=1)
    dff_cluster = dff_cluster.mean()
    dff_cluster = pd.DataFrame(dff_cluster)
    dff_cluster = dff_cluster.reset_index()
    dff_cluster = dff_cluster.rename(columns={'index':'Variables', 0:'Cluster_Values'})
    dff_cluster = dff_cluster.set_index('Variables')
    
    # Clean country data
    dff_country = df[df['Country']==country]
    dff_country = dff_country[dff_country['Year']==2019]
    dff_country = dff_country.drop(['Country', 'Rank', 'Change from Previous Year'], axis=1)
    dff_country = dff_country.rename(columns={'Year':'Variables'})
    dff_country = dff_country.set_index('Variables').T
    
    # Concat DF
    w = pd.concat([dff_cluster, dff_country], axis=1)
    w.rename(columns={0:'Group', w.columns[1]:country}, inplace=True)
    
    w['Dif'] = w['Cluster_Values'] - w[country]
    
    return w.sort_values(by='Dif')

# %%
f_country_compare__(country,2)
# Out:
#                                   Cluster_Values  Venezuela   Dif
# Variables
# E1: Economy                                 7.61       8.60 -0.99
# P3: Human Rights                            8.16       9.00 -0.84
# P1: State Legitimacy                        8.68       9.30 -0.62
# C2: Factionalized Elites                    8.85       8.80  0.05
# P2: Public Services                         8.59       8.30  0.29
# C3: Group Grievance                         8.01       7.60  0.41
# C1: Security Apparatus                      8.19       7.40  0.79
# E2: Economic Inequality                     7.72       6.90  0.82
# E3: Human Flight and Brain Drain            7.21       6.10  1.11
# S1: Demographic Pressures                   8.36       6.20  2.16
# S2: Refugees and IDPs                       8.13       5.60  2.53
# X1: External Intervention                   8.04       5.50  2.54
# Total                                      97.56      89.30  8.26

# %%
dff_year = df[df['Year']=='2019']
dff_year = dff_year.drop(['Year', 'Rank', 'Change from Previous Year'], axis=1)
dff_year = dff_year.set_index('Country')
    
X = dff_year.values[:,1:]
X = np.nan_to_num(X)
Clus_dataSet = StandardScaler().fit_transform(X)

clusterNum = 5
k_means = KMeans(init = "k-means++", n_clusters = clusterNum, n_init = 12)
k_means.fit(X)
labels = k_means.labels_

dff_year["Clus_km"] = labels

# %%
df_peace = pd.read_excel('Data/Global Peace Index.xlsx')

# %%
df_peace = df_peace.set_index('Country')
df_peace.head()
# Out:
#              Peace_index
# Country
# Afghanistan         3574
# Albania             1821
# Algeria             2219
# Angola              2012
# Argentina           1989

# %%
df_fei_peace = pd.merge(dff_year, df_peace, left_index=True, right_index=True)

# %%
df_fei_peace.head()
# Out:
#                            Total  C1: Security Apparatus  \
# Country
# Yemen                     113.50                   10.00
# Somalia                   112.30                    9.60
# South Sudan               112.20                    9.70
# Congo Democratic Republic 110.20                    8.80
# Central African Republic  108.90                    8.60
#
#                            C2: Factionalized Elites  C3: Group Grievance  \
# Country
# Yemen                                         10.00                 9.60
# Somalia                                       10.00                 8.90
# South Sudan                                    9.70                 9.40
# Congo Democratic Republic                      9.80                10.00
# Central African Republic                       9.40                 8.30
#
#                            E1: Economy  E2: Economic Inequality  \
# Country
# Yemen                             9.70                     8.10
# Somalia                           8.80                     9.40
# South Sudan                       9.80                     8.90
# Congo Democratic Republic         8.30                     8.60
# Central African Republic          8.70                     9.90
#
#                            E3: Human Flight and Brain Drain  \
# Country
# Yemen                                                  7.30
# Somalia                                                9.20
# South Sudan                                            6.50
# Congo Democratic Republic                              7.00
# Central African Republic                               7.10
#
#                            P1: State Legitimacy  P2: Public Services  \
# Country
# Yemen                                      9.80                 9.80
# Somalia                                    9.00                 9.40
# South Sudan                               10.00                 9.80
# Congo Democratic Republic                  9.40                 9.20
# Central African Republic                   9.10                10.00
#
#                            P3: Human Rights  S1: Demographic Pressures  \
# Country
# Yemen                                  9.90                       9.70
# Somalia                                9.30                      10.00
# South Sudan                            9.30                       9.70
# Congo Democratic Republic              9.60                       9.80
# Central African Republic               9.50                       9.10
#
#                            S2: Refugees and IDPs  X1: External Intervention  \
# Country
# Yemen                                       9.60                      10.00
# Somalia                                     9.40                       9.20
# South Sudan                                10.00                       9.40
# Congo Democratic Republic                  10.00                       9.70
# Central African Republic                   10.00                       9.20
#
#                            Clus_km  Peace_index
# Country
# Yemen                            2         3412
# Somalia                          2         3300
# South Sudan                      2         3526
# Congo Democratic Republic        2         3218
# Central African Republic         2         3296

# %%
df_fei_peace.reset_index(inplace=True)

# %%
fig = px.scatter(df_fei_peace, x='Total', y='Peace_index',
                 color='Clus_km', hover_name='Country', marginal_x="histogram", marginal_y="histogram", trendline='ols')


fig.update_layout(title=go.layout.Title(text='FSI / Peace Index'), showlegend=False)

pyo.plot(fig)
# Out:
# C:\Users\Diego\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning:
#
# Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
# 'temp-plot.html'

# %%
w = df[df['Country']==country]
w = w.drop(['Country', 'Rank', 'Change from Previous Year', 'Total'], axis=1)
w = w.set_index('Year')
w.loc[(w.index >='2011') & (w.index <= 2015)]
# Out:
#       C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# Year
# 2011                    7.00                      7.30                 7.00
# 2012                    6.70                      7.30                 6.70
# 2013                    6.50                      7.30                 6.40
# 2014                    6.20                      7.70                 6.80
# 2015                    6.50                      8.10                 7.30
#
#       E1: Economy  E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# Year
# 2011         6.10                     7.30                              6.40
# 2012         5.90                     7.20                              6.10
# 2013         5.40                     6.90                              5.80
# 2014         5.50                     6.90                              5.50
# 2015         6.50                     6.70                              5.20
#
#       P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# Year
# 2011                  7.50                 5.80              7.40
# 2012                  7.90                 6.30              7.70
# 2013                  7.60                 6.50              7.70
# 2014                  7.70                 7.50              7.80
# 2015                  8.60                 7.20              8.30
#
#       S1: Demographic Pressures  S2: Refugees and IDPs  \
# Year
# 2011                       6.00                   4.80
# 2012                       5.70                   4.50
# 2013                       5.40                   4.80
# 2014                       5.40                   5.10
# 2015                       5.10                   4.80
#
#       X1: External Intervention
# Year
# 2011                       5.50
# 2012                       5.20
# 2013                       4.90
# 2014                       4.60
# 2015                       4.30
